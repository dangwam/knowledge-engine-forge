# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchsummary import summary
import logging
import matplotlib.pyplot as plt
import yfinance as yf
from matplotlib.pyplot import figure
import random
# Set random seed for reproducibility
random_seed = 42
random.seed(random_seed)
np.random.seed(random_seed)
torch.manual_seed(random_seed)
from alpha_vantage.timeseries import TimeSeries
import requests
import pandas as pd
from io import BytesIO

AV_API_URL = "https://www.alphavantage.co/query"
ALPHA_VANTAGE_API_KEY = "6OSEAGNZPLLNQJO8"


print("All libraries loaded")
########################################################################################################################################################
config = {
    "alpha_vantage": {
        "key": "demo", # you can use the demo API key for this project, but please make sure to get your own API key at https://www.alphavantage.co/support/#api-key
        "symbol": "SPY",
        "outputsize": "full",
        "key_adjusted_close": "5. adjusted close",
    },
    "data": {
         "window_size": 20,
         "train_split_size": 0.90,
       
    }, 
    "plots": {
        "xticks_interval": 90, # show a date every 90 days
        "color_actual": "#001f3f",
        "color_train": "#3D9970",
        "color_val": "#0074D9",
        "color_pred_train": "#3D9970",
        "color_pred_val": "#0074D9",
        "color_pred_test": "#FF4136",
    },
    "model": {
        "input_size": 1, # since we are only using 1 feature, close price
        "num_lstm_layers": 2,
        "lstm_size": 64,
        "dropout": 0.2,
    },
    "training": {
        "device": "cpu", # "cuda" or "cpu"
        "batch_size": 32,
        "num_epoch": 100,
        "learning_rate": 0.01,
        "scheduler_step_size": 40,
    }
}

def download_data(config):
        
    # Replace 'SPY' with the ticker symbol of the stock you want to fetch
        ticker_symbol = 'SPY'

    # Fetch historical data from Yahoo Finance
        df = yf.download(ticker_symbol, start='2010-01-01', end='2024-01-05')
       
    # Extract date in yyyy-mm-dd format
        df['Date'] = df.index.strftime('%Y-%m-%d')

    # Extract adjusted close price
        df['Adjusted_Close_Price'] = df['close']
    # Store the data in an Excel file
        df.to_excel('spy_data_lstm_yahoo.xlsx', index=False)

    # Read the data from the Excel file
        #df = pd.read_excel('spy_data_lstm_yahoo.xlsx')

    # Find the total number of data points
        num_data_points = len(df)
  
    # Find the date range (start and end dates)
        data_date = df['Date']
        data_close_price = df['Adjusted_Close_Price']
        volume = df['Volume']
        start_date = df['Date'].iloc[0]
        end_date = df['Date'].iloc[-1]
        display_date_range = f"{start_date} to {end_date}"
        print("Number data points", num_data_points, display_date_range)

        return data_date, data_close_price, num_data_points, display_date_range, volume

data_date, data_close_price, num_data_points, display_date_range, volume = download_data(config)

'''
# plot

fig = figure(figsize=(25, 5), dpi=80)
fig.patch.set_facecolor((1.0, 1.0, 1.0))
plt.plot(data_date, data_close_price, color=config["plots"]["color_actual"])
xticks = [data_date[i] if ((i%config["plots"]["xticks_interval"]==0 and (num_data_points-i) > config["plots"]["xticks_interval"]) or i==num_data_points-1) else None for i in range(num_data_points)] # make x ticks nice
x = np.arange(0,len(xticks))
plt.xticks(x, xticks, rotation='vertical')
plt.title("Daily close price for " + config["alpha_vantage"]["symbol"] + ", " + display_date_range)
plt.grid(which='major', axis='y', linestyle='--')
#plt.show()
'''
# Block-2::Data preparation: normalizing raw financial data
# normalize
class Normalizer():
    def __init__(self):
        self.mu = None
        self.sd = None

    def fit_transform(self, x):
        self.mu = np.mean(x, axis=(0))
        self.sd = np.std(x, axis=(0))
        normalized_x = (x - self.mu)/self.sd
        return normalized_x

    def inverse_transform(self, x):
        return (x*self.sd) + self.mu
        
scaler = Normalizer()
normalized_data_close_price = scaler.fit_transform(data_close_price)

print("****************************************************")
print(normalized_data_close_price)
print("****************************************************")

def prepare_data_x(x, window_size):
    # perform windowing
    # Ensure that x is a NumPy array
    x = normalized_data_close_price.values
    n_row = x.shape[0] - window_size + 1
    output = np.lib.stride_tricks.as_strided(x, shape=(n_row, window_size), strides=(x.strides[0], x.strides[0]))
            
    return output[:-1], output[-1]


def prepare_data_y(x, window_size):
    # # perform simple moving average
    # output = np.convolve(x, np.ones(window_size), 'valid') / window_size
    # Ensure that x is a NumPy array
    x = normalized_data_close_price.values
    # use the next day as label
    output = x[window_size:]
    return output

data_x, data_x_unseen = prepare_data_x(normalized_data_close_price, window_size=config["data"]["window_size"])
data_y = prepare_data_y(normalized_data_close_price, window_size=config["data"]["window_size"])
print(len(data_x),len(data_y),len(data_x_unseen))
#print(normalized_data_close_price.head(21))
# split dataset

split_index = int(data_y.shape[0]*config["data"]["train_split_size"])
data_x_train = data_x[:split_index]
data_x_val = data_x[split_index:]
data_y_train = data_y[:split_index]
data_y_val = data_y[split_index:]

class TimeSeriesDataset(Dataset):
    def __init__(self, x, y):
        x = np.expand_dims(x, 2) # in our case, we have only 1 feature, so we need to convert `x` into [batch, sequence, features] for LSTM
        self.x = x.astype(np.float32)
        self.y = y.astype(np.float32)
        
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return (self.x[idx], self.y[idx])

dataset_train = TimeSeriesDataset(data_x_train, data_y_train)
dataset_val = TimeSeriesDataset(data_x_val, data_y_val)

print("Train data shape", dataset_train.x.shape, dataset_train.y.shape)
print("Validation data shape", dataset_val.x.shape, dataset_val.y.shape)

train_dataloader = DataLoader(dataset_train, batch_size=config["training"]["batch_size"], shuffle=True)
val_dataloader = DataLoader(dataset_val, batch_size=config["training"]["batch_size"], shuffle=True)

#Iterate Through Data Loaders:
print("Iterate Through Data Loaders:")
for batch_idx, (input_data, target_data) in enumerate(train_dataloader):
        print(f"Batch {batch_idx}: Input Shape: {input_data.shape}, Target Shape: {target_data.shape}")
        if batch_idx < 3:
            print(f"Batch {batch_idx}: Input Shape: {input_data.shape}, Target Shape: {target_data.shape}")

class LSTMModel(nn.Module):
    def __init__(self, input_size=1, hidden_layer_size=64, num_layers=2, output_size=1, dropout=0.1):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.linear_1 = nn.Linear(input_size, hidden_layer_size)
        self.relu = nn.ReLU()
        self.lstm = nn.LSTM(hidden_layer_size, hidden_size=self.hidden_layer_size, num_layers=num_layers, batch_first=True)
        self.dropout = nn.Dropout(dropout)
        self.linear_2 = nn.Linear(num_layers*hidden_layer_size, output_size)
        
        self.init_weights()

    def init_weights(self):
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                 nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                 nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                 nn.init.orthogonal_(param)

    def forward(self, x):
        batchsize = x.shape[0]

        # layer 1
        x = self.linear_1(x)
        x = self.relu(x)
        
        # LSTM layer
        lstm_out, (h_n, c_n) = self.lstm(x)

        # reshape output from hidden cell into [batch, features] for `linear_2`
        x = h_n.permute(1, 0, 2).reshape(batchsize, -1) 
        
        # layer 2
        x = self.dropout(x)
        predictions = self.linear_2(x)
        return predictions[:,-1]

def run_epoch(dataloader, is_training=False):
    epoch_loss = 0

    if is_training:
        model.train()
    else:
        model.eval()

    for idx, (x, y) in enumerate(dataloader):
        if is_training:
            optimizer.zero_grad()

        batchsize = x.shape[0]

        x = x.to(config["training"]["device"])
        y = y.to(config["training"]["device"])

        out = model(x)
        loss = criterion(out.contiguous(), y.contiguous())

        if is_training:
            loss.backward()
            optimizer.step()

        epoch_loss += (loss.detach().item() / batchsize)

    lr = scheduler.get_last_lr()[0]

    return epoch_loss, lr

train_dataloader = DataLoader(dataset_train, batch_size=config["training"]["batch_size"], shuffle=True)

#print(len(train_dataloader))
for batch in train_dataloader:
    # Process the batch
    x, y = batch
    #print(x.shape, y.shape)

val_dataloader = DataLoader(dataset_val, batch_size=config["training"]["batch_size"], shuffle=True)
print(len(val_dataloader))
for batch in val_dataloader:
    # Process the batch
    x, y = batch
    #print(x.shape, y.shape)

model = LSTMModel(input_size=config["model"]["input_size"], hidden_layer_size=config["model"]["lstm_size"], num_layers=config["model"]["num_lstm_layers"], output_size=1, dropout=config["model"]["dropout"])
model = model.to(config["training"]["device"])

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=config["training"]["learning_rate"], betas=(0.9, 0.98), eps=1e-9)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=config["training"]["scheduler_step_size"], gamma=0.1)

for epoch in range(config["training"]["num_epoch"]):
    loss_train, lr_train = run_epoch(train_dataloader, is_training=True)
    loss_val, lr_val = run_epoch(val_dataloader)
    scheduler.step()
    
    print('Epoch[{}/{}] | loss train:{:.6f}, test:{:.6f} | lr:{:.6f}'
              .format(epoch+1, config["training"]["num_epoch"], loss_train, loss_val, lr_train))

# here we re-initialize dataloader so the data doesn't shuffled, so we can plot the values by date

train_dataloader = DataLoader(dataset_train, batch_size=config["training"]["batch_size"], shuffle=False)
val_dataloader = DataLoader(dataset_val, batch_size=config["training"]["batch_size"], shuffle=False)

model.eval()
# predict on the training data, to see how well the model managed to learn and memorize
predicted_train = np.array([])

for idx, (x, y) in enumerate(train_dataloader):
    x = x.to(config["training"]["device"])
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_train = np.concatenate((predicted_train, out))

# predict on the validation data, to see how the model does

predicted_val = np.array([])

for idx, (x, y) in enumerate(val_dataloader):
    x = x.to(config["training"]["device"])
    out = model(x)
    out = out.cpu().detach().numpy()
    predicted_val = np.concatenate((predicted_val, out))

# prepare data for plotting
print("----plottings--------------")
to_plot_data_y_train_pred = np.zeros(num_data_points)
to_plot_data_y_val_pred = np.zeros(num_data_points)

to_plot_data_y_train_pred[config["data"]["window_size"]:split_index+config["data"]["window_size"]] = scaler.inverse_transform(predicted_train)
to_plot_data_y_val_pred[split_index+config["data"]["window_size"]:] = scaler.inverse_transform(predicted_val)

to_plot_data_y_train_pred = np.where(to_plot_data_y_train_pred == 0, None, to_plot_data_y_train_pred)
to_plot_data_y_val_pred = np.where(to_plot_data_y_val_pred == 0, None, to_plot_data_y_val_pred)

# plots

fig = figure(figsize=(25, 5), dpi=80)
fig.patch.set_facecolor((1.0, 1.0, 1.0))
plt.plot(data_date, data_close_price, label="Actual prices", color=config["plots"]["color_actual"])
plt.plot(data_date, to_plot_data_y_train_pred, label="Predicted prices (train)", color=config["plots"]["color_pred_train"])
plt.plot(data_date, to_plot_data_y_val_pred, label="Predicted prices (validation)", color=config["plots"]["color_pred_val"])
plt.title("Compare predicted prices to actual prices")
xticks = [data_date[i] if ((i%config["plots"]["xticks_interval"]==0 and (num_data_points-i) > config["plots"]["xticks_interval"]) or i==num_data_points-1) else None for i in range(num_data_points)] # make x ticks nice
x = np.arange(0,len(xticks))
plt.xticks(x, xticks, rotation='vertical')
plt.grid(which='major', axis='y', linestyle='--')
plt.legend()
plt.show()

# predict the closing price of the next trading day

model.eval()

x = torch.tensor(data_x_unseen).float().to(config["training"]["device"]).unsqueeze(0).unsqueeze(2) # this is the data type and shape required, [batch, sequence, feature]
prediction = model(x)
prediction = prediction.cpu().detach().numpy()

# prepare plots

plot_range = 10
to_plot_data_y_val = np.zeros(plot_range)
to_plot_data_y_val_pred = np.zeros(plot_range)
to_plot_data_y_test_pred = np.zeros(plot_range)

to_plot_data_y_val[:plot_range-1] = scaler.inverse_transform(data_y_val)[-plot_range+1:]
to_plot_data_y_val_pred[:plot_range-1] = scaler.inverse_transform(predicted_val)[-plot_range+1:]

to_plot_data_y_test_pred[plot_range-1] = scaler.inverse_transform(prediction)[0]
to_plot_data_y_val = np.where(to_plot_data_y_val == 0, None, to_plot_data_y_val)
to_plot_data_y_val_pred = np.where(to_plot_data_y_val_pred == 0, None, to_plot_data_y_val_pred)

to_plot_data_y_test_pred = np.where(to_plot_data_y_test_pred == 0, None, to_plot_data_y_test_pred)

# plot

plot_date_test = data_date[-plot_range+1:]
plot_date_test = pd.concat([plot_date_test, pd.Series(["tomorrow"])], ignore_index=True)

fig = figure(figsize=(25, 5), dpi=80)
fig.patch.set_facecolor((1.0, 1.0, 1.0))
plt.plot(plot_date_test, to_plot_data_y_val, label="Actual prices", marker=".", markersize=10, color=config["plots"]["color_actual"])
plt.plot(plot_date_test, to_plot_data_y_val_pred, label="Past predicted prices", marker=".", markersize=10, color=config["plots"]["color_pred_val"])
plt.plot(plot_date_test, to_plot_data_y_test_pred, label="Predicted price for next day", marker=".", markersize=20, color=config["plots"]["color_pred_test"])
plt.title("Predicted close price of the next trading day")
plt.grid(which='major', axis='y', linestyle='--')
plt.legend()
plt.show()

print("Predicted close price of the next trading day:", round(to_plot_data_y_test_pred[plot_range-1], 2))

# Prepare data for the DataFrame
data = {
    'date': data_date[config["data"]["window_size"] + split_index:],  # Adjust the starting index to align with the predictions
    'actual_close_price': scaler.inverse_transform(data_y_val),
    'predicted_price': scaler.inverse_transform(predicted_val),
}

# Create the DataFrame
df = pd.DataFrame(data)

# Calculate the difference between actual and predicted prices
df['difference'] = df['actual_close_price'] - df['predicted_price']
df['volume'] = volume

# Display the DataFrame
print(df.tail(5))
df.to_excel('spy_lstm_predictions.xlsx', index=False)
# Out:
# All libraries loaded
# [*********************100%%**********************]  1 of 1 completed
# Number data points 3525 2010-01-04 to 2024-01-04
# ****************************************************
# Date
# 2010-01-04   -1.271682
# 2010-01-05   -1.269646
# 2010-01-06   -1.269103
# 2010-01-07   -1.265845
# 2010-01-08   -1.263266
#                 ...
# 2023-12-28    2.167700
# 2023-12-29    2.155516
# 2024-01-02    2.132031
# 2024-01-03    2.097952
# 2024-01-04    2.084620
# Name: Adjusted_Close_Price, Length: 3525, dtype: float64
# ****************************************************
# 3505 3505 20
# Train data shape (3154, 20, 1) (3154,)
# Validation data shape (351, 20, 1) (351,)
# Iterate Through Data Loaders:
# Batch 0: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 0: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 1: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 1: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 2: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 2: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 3: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 4: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 5: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 6: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 7: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 8: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 9: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 10: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 11: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 12: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 13: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 14: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 15: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 16: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 17: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 18: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 19: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 20: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 21: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 22: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 23: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 24: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 25: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 26: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 27: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 28: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 29: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 30: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 31: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 32: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 33: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 34: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 35: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 36: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 37: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 38: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 39: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 40: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 41: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 42: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 43: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 44: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 45: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 46: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 47: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 48: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 49: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 50: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 51: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 52: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 53: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 54: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 55: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 56: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 57: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 58: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 59: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 60: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 61: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 62: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 63: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 64: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 65: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 66: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 67: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 68: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 69: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 70: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 71: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 72: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 73: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 74: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 75: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 76: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 77: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 78: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 79: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 80: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 81: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 82: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 83: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 84: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 85: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 86: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 87: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 88: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 89: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 90: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 91: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 92: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 93: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 94: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 95: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 96: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 97: Input Shape: torch.Size([32, 20, 1]), Target Shape: torch.Size([32])
# Batch 98: Input Shape: torch.Size([18, 20, 1]), Target Shape: torch.Size([18])
# 11
# Epoch[1/100] | loss train:0.102514, test:0.002953 | lr:0.010000
# Epoch[2/100] | loss train:0.020344, test:0.001681 | lr:0.010000
# Epoch[3/100] | loss train:0.021789, test:0.000854 | lr:0.010000
# Epoch[4/100] | loss train:0.021015, test:0.001789 | lr:0.010000
# Epoch[5/100] | loss train:0.019098, test:0.002019 | lr:0.010000
# Epoch[6/100] | loss train:0.018919, test:0.002741 | lr:0.010000
# Epoch[7/100] | loss train:0.018135, test:0.001010 | lr:0.010000
# Epoch[8/100] | loss train:0.015058, test:0.001615 | lr:0.010000
# Epoch[9/100] | loss train:0.015289, test:0.001587 | lr:0.010000
# Epoch[10/100] | loss train:0.016464, test:0.002511 | lr:0.010000
# Epoch[11/100] | loss train:0.017464, test:0.000575 | lr:0.010000
# Epoch[12/100] | loss train:0.015582, test:0.000822 | lr:0.010000
# Epoch[13/100] | loss train:0.013863, test:0.008086 | lr:0.010000
# Epoch[14/100] | loss train:0.016458, test:0.003479 | lr:0.010000
# Epoch[15/100] | loss train:0.014737, test:0.007845 | lr:0.010000
# Epoch[16/100] | loss train:0.014048, test:0.000679 | lr:0.010000
# Epoch[17/100] | loss train:0.012899, test:0.002594 | lr:0.010000
# Epoch[18/100] | loss train:0.016571, test:0.003525 | lr:0.010000
# Epoch[19/100] | loss train:0.014511, test:0.001888 | lr:0.010000
# Epoch[20/100] | loss train:0.011196, test:0.000719 | lr:0.010000
# Epoch[21/100] | loss train:0.013032, test:0.006850 | lr:0.010000
# Epoch[22/100] | loss train:0.013210, test:0.001319 | lr:0.010000
# Epoch[23/100] | loss train:0.013070, test:0.010988 | lr:0.010000
# Epoch[24/100] | loss train:0.013948, test:0.000550 | lr:0.010000
# Epoch[25/100] | loss train:0.013552, test:0.001455 | lr:0.010000
# Epoch[26/100] | loss train:0.013229, test:0.000740 | lr:0.010000
# Epoch[27/100] | loss train:0.011659, test:0.001039 | lr:0.010000
# Epoch[28/100] | loss train:0.013251, test:0.006175 | lr:0.010000
# Epoch[29/100] | loss train:0.011692, test:0.000784 | lr:0.010000
# Epoch[30/100] | loss train:0.010804, test:0.002141 | lr:0.010000
# Epoch[31/100] | loss train:0.011942, test:0.001249 | lr:0.010000
# Epoch[32/100] | loss train:0.011010, test:0.000614 | lr:0.010000
# Epoch[33/100] | loss train:0.011818, test:0.000664 | lr:0.010000
# Epoch[34/100] | loss train:0.010580, test:0.001576 | lr:0.010000
# Epoch[35/100] | loss train:0.012452, test:0.001466 | lr:0.010000
# Epoch[36/100] | loss train:0.011975, test:0.000580 | lr:0.010000
# Epoch[37/100] | loss train:0.011404, test:0.001977 | lr:0.010000
# Epoch[38/100] | loss train:0.010301, test:0.000731 | lr:0.010000
# Epoch[39/100] | loss train:0.011156, test:0.000754 | lr:0.010000
# Epoch[40/100] | loss train:0.011674, test:0.000793 | lr:0.010000
# Epoch[41/100] | loss train:0.008354, test:0.000542 | lr:0.001000
# Epoch[42/100] | loss train:0.007879, test:0.000888 | lr:0.001000
# Epoch[43/100] | loss train:0.007597, test:0.000528 | lr:0.001000
# Epoch[44/100] | loss train:0.007473, test:0.000812 | lr:0.001000
# Epoch[45/100] | loss train:0.007713, test:0.000519 | lr:0.001000
# Epoch[46/100] | loss train:0.007513, test:0.000663 | lr:0.001000
# Epoch[47/100] | loss train:0.007693, test:0.000581 | lr:0.001000
# Epoch[48/100] | loss train:0.007801, test:0.000527 | lr:0.001000
# Epoch[49/100] | loss train:0.007392, test:0.000554 | lr:0.001000
# Epoch[50/100] | loss train:0.007263, test:0.000859 | lr:0.001000
# Epoch[51/100] | loss train:0.007000, test:0.000533 | lr:0.001000
# Epoch[52/100] | loss train:0.007389, test:0.000553 | lr:0.001000
# Epoch[53/100] | loss train:0.007574, test:0.000582 | lr:0.001000
# Epoch[54/100] | loss train:0.007387, test:0.000608 | lr:0.001000
# Epoch[55/100] | loss train:0.007425, test:0.000511 | lr:0.001000
# Epoch[56/100] | loss train:0.007167, test:0.000737 | lr:0.001000
# Epoch[57/100] | loss train:0.007105, test:0.000816 | lr:0.001000
# Epoch[58/100] | loss train:0.007747, test:0.000615 | lr:0.001000
# Epoch[59/100] | loss train:0.006972, test:0.000499 | lr:0.001000
# Epoch[60/100] | loss train:0.006674, test:0.000520 | lr:0.001000
# Epoch[61/100] | loss train:0.007007, test:0.001002 | lr:0.001000
# Epoch[62/100] | loss train:0.007477, test:0.000525 | lr:0.001000
# Epoch[63/100] | loss train:0.007714, test:0.000561 | lr:0.001000
# Epoch[64/100] | loss train:0.007192, test:0.000618 | lr:0.001000
# Epoch[65/100] | loss train:0.007341, test:0.000558 | lr:0.001000
# Epoch[66/100] | loss train:0.006957, test:0.000535 | lr:0.001000
# Epoch[67/100] | loss train:0.006933, test:0.000800 | lr:0.001000
# Epoch[68/100] | loss train:0.006915, test:0.000523 | lr:0.001000
# Epoch[69/100] | loss train:0.007022, test:0.000497 | lr:0.001000
# Epoch[70/100] | loss train:0.007108, test:0.000606 | lr:0.001000
# Epoch[71/100] | loss train:0.007061, test:0.000682 | lr:0.001000
# Epoch[72/100] | loss train:0.007931, test:0.000507 | lr:0.001000
# Epoch[73/100] | loss train:0.007019, test:0.000633 | lr:0.001000
# Epoch[74/100] | loss train:0.007627, test:0.000551 | lr:0.001000
# Epoch[75/100] | loss train:0.007124, test:0.000628 | lr:0.001000
# Epoch[76/100] | loss train:0.007115, test:0.000550 | lr:0.001000
# Epoch[77/100] | loss train:0.006845, test:0.000529 | lr:0.001000
# Epoch[78/100] | loss train:0.007349, test:0.000499 | lr:0.001000
# Epoch[79/100] | loss train:0.007013, test:0.000607 | lr:0.001000
# Epoch[80/100] | loss train:0.007821, test:0.000825 | lr:0.001000
# Epoch[81/100] | loss train:0.006387, test:0.000495 | lr:0.000100
# Epoch[82/100] | loss train:0.006478, test:0.000577 | lr:0.000100
# Epoch[83/100] | loss train:0.006830, test:0.000535 | lr:0.000100
# Epoch[84/100] | loss train:0.007005, test:0.000526 | lr:0.000100
# Epoch[85/100] | loss train:0.007230, test:0.000505 | lr:0.000100
# Epoch[86/100] | loss train:0.006691, test:0.000516 | lr:0.000100
# Epoch[87/100] | loss train:0.007096, test:0.000501 | lr:0.000100
# Epoch[88/100] | loss train:0.006690, test:0.000498 | lr:0.000100
# Epoch[89/100] | loss train:0.006936, test:0.000499 | lr:0.000100
# Epoch[90/100] | loss train:0.006714, test:0.000501 | lr:0.000100
# Epoch[91/100] | loss train:0.006978, test:0.000498 | lr:0.000100
# Epoch[92/100] | loss train:0.006959, test:0.000498 | lr:0.000100
# Epoch[93/100] | loss train:0.006763, test:0.000497 | lr:0.000100
# Epoch[94/100] | loss train:0.007191, test:0.000527 | lr:0.000100
# Epoch[95/100] | loss train:0.006459, test:0.000512 | lr:0.000100
# Epoch[96/100] | loss train:0.006893, test:0.000493 | lr:0.000100
# Epoch[97/100] | loss train:0.006892, test:0.000547 | lr:0.000100
# Epoch[98/100] | loss train:0.006556, test:0.000505 | lr:0.000100
# Epoch[99/100] | loss train:0.006499, test:0.000577 | lr:0.000100
# Epoch[100/100] | loss train:0.007022, test:0.000496 | lr:0.000100
# ----plottings--------------
# C:\Users\MAYANK DANGWAL\AppData\Local\Temp\ipykernel_17956\612024284.py:332: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xticks = [data_date[i] if ((i%config["plots"]["xticks_interval"]==0 and (num_data_points-i) > config["plots"]["xticks_interval"]) or i==num_data_points-1) else None for i in range(num_data_points)] # make x ticks nice
# Predicted close price of the next trading day: 463.92
#                   date  actual_close_price  predicted_price  difference  \
# Date
# 2023-12-28  2023-12-28          476.690002       476.558064    0.131938
# 2023-12-29  2023-12-29          475.309998       476.338924   -1.028926
# 2024-01-02  2024-01-02          472.649994       473.507408   -0.857414
# 2024-01-03  2024-01-03          468.790009       469.396452   -0.606443
# 2024-01-04  2024-01-04          467.279999       465.070271    2.209728
#
#                volume
# Date
# 2023-12-28   77158100
# 2023-12-29  122234100
# 2024-01-02  123623700
# 2024-01-03  103585900
# 2024-01-04   84150500
